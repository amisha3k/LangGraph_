# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver
import os

# %%
load_dotenv ()
llm = ChatGroq(
    groq_api_key=os.getenv("GROQ_API_KEY") ,
    model="llama-3.3-70b-versatile"
)

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!', 'explanation': 'A classic play on words. This joke is an example of a pun, which is a type of wordplay that uses multiple meanings of a word to create humor.\n\nIn this joke, the word "crusty" has a double meaning. In one sense, "crusty" refers to the outer layer of a pizza, which is typically crispy and crunchy. However, "crusty" can also mean being irritable, grumpy, or having a bad temper.\n\nThe joke sets up the expectation that the pizza is in a bad mood, and the punchline subverts this expectation by using the word "crusty" in a way that is both literal (referring to the pizza\'s crust) and figurative (referring to the pizza\'s emotional state). The humor comes from the unexpected twist on the word\'s meaning, creating a clever and amusing connection between the setup and the punchline.\n\nIn essence, the joke is saying that the pizza is feeling grumpy,
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!', 'explanation': 'A classic play on words. This joke is an example of a pun, which is a type of wordplay that uses multiple meanings of a word to create humor.\n\nIn this joke, the word "crusty" has a double meaning. In one sense, "crusty" refers to the outer layer of a pizza, which is typically crispy and crunchy. However, "crusty" can also mean being irritable, grumpy, or having a bad temper.\n\nThe joke sets up the expectation that the pizza is in a bad mood, and the punchline subverts this expectation by using the word "crusty" in a way that is both literal (referring to the pizza\'s crust) and figurative (referring to the pizza\'s emotional state). The humor comes from the unexpected twist on the word\'s meaning, creating a clever and amusing connection between the setup and the punchline.\n\nIn essence, the joke is saying that the pizza is feeling grumpy
# ...

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti refuse to get married?\n\nBecause it was afraid of getting tangled up in a long-term relationship!',
# ...

# %%
workflow.get_state(config2)
# Out:
# StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti refuse to get married?\n\nBecause it was afraid of getting tangled up in a long-term relationship!', 'explanation': 'A deliciously clever joke. Here\'s a breakdown of why it\'s funny:\n\nThe joke is a play on words, using the physical properties of spaghetti to make a pun on the concept of relationships. Spaghetti is a type of long, thin, and flexible pasta that can easily become tangled or knotted. In the joke, the spaghetti refuses to get married because it\'s afraid of getting "tangled up" in a long-term relationship.\n\nThe word "tangled" has a double meaning here. In a literal sense, spaghetti can become physically tangled, which is a common experience when trying to eat or cook with it. However, in the context of relationships, "tangled" can also mean complicated, messy, or entangled in a web of emotions and commitments.\n\nThe joke relies on this wordplay to create a humorous connection between the physical
# ...

# %% [markdown]
# #Time Travel

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty!', 'explanation': 'A classic play on words. This joke is an example of a pun, which is a type of wordplay that uses multiple meanings of a word to create humor.\n\nIn this joke, the word "crusty" has a double meaning. In one sense, "crusty" refers to the outer layer of a pizza, which is typically crispy and crunchy. However, "crusty" can also mean being irritable, grumpy, or having a bad temper.\n\nThe joke sets up the expectation that the pizza is in a bad mood, and the punchline subverts this expectation by using the word "crusty" in a way that is both literal (referring to the pizza\'s crust) and figurative (referring to the pizza\'s emotional state). The humor comes from the unexpected twist on the word\'s meaning, creating a clever and amusing connection between the setup and the punchline.\n\nIn essence, the joke is saying that the pizza is feeling grumpy
# ...

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti refuse to get married?\n\nBecause it was afraid of getting tangled up in a long-term relationship!', 'explanation': 'A deliciously clever joke. Here\'s a breakdown of why it\'s funny:\n\nThe joke is a play on words, using the physical properties of spaghetti to make a pun on the concept of relationships. Spaghetti is a type of long, thin, and flexible pasta that can easily become tangled or knotted. In the joke, the spaghetti refuses to get married because it\'s afraid of getting "tangled up" in a long-term relationship.\n\nThe word "tangled" has a double meaning here. In a literal sense, spaghetti can become physically tangled, which is a common experience when trying to eat or cook with it. However, in the context of relationships, "tangled" can also mean complicated, messy, or entangled in a web of emotions and commitments.\n\nThe joke relies on this wordplay to create a humorous connection between the physica
# ...

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f06cc6e-7232-6cb1-8000-f71609e6cec5"}})
# Out:
# StateSnapshot(values={}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, metadata=None, created_at=None, parent_config=None, tasks=(), interrupts=())

# %%
workflow.invoke(None, {"configurable": {"thread_id": "2", "checkpoint_id": "1f0b79c9-88af-6a27-8000-8a25be4f0a1d"}})
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti refuse to get married?\n\nBecause it was afraid of getting tangled up in a relationship!',
# ...

# %% [markdown]
# #Updating State

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f06cc6e-7232-6cb1-8000-f71609e6cec5","checkpoint_ns":""}},{'topic':'burger'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0b7c27-4849-65cd-8000-fcbc7575f5d7'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'burger'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b7c27-4849-65cd-8000-fcbc7575f5d7'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2025-11-02T08:03:45.486996+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, tasks=(PregelTask(id='31db44b9-1279-7dac-4346-860cefddcd31', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f0b7c27-4849-65cd-8000-fcbc7575f5d7"}})
# Out:
# {'topic': 'burger',
#  'joke': 'Why did the burger go to therapy?\n\nBecause it was feeling a little "well-done" and was struggling to "beef" up its self-esteem!',
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'burger', 'joke': 'Why did the burger go to therapy?\n\nBecause it was feeling a little "well-done" and was struggling to "beef" up its self-esteem!', 'explanation': 'A clever play on words. This joke relies on a combination of puns and wordplay to create a humorous effect. Here\'s a breakdown of the explanation:\n\n1. **"Well-done"**: In this context, "well-done" has a double meaning. In cooking, a burger can be cooked to a "well-done" state, meaning it\'s fully cooked and possibly overcooked. However, the phrase "feeling well-done" is also a pun on the phrase "feeling down," which is a common idiomatic expression for feeling sad or depressed. So, the burger is feeling sad, but the word "well-done" is used instead of "down" to create a clever connection to the burger\'s culinary state.\n\n2. **"Beef" up its self-esteem**: This phrase is another example of wordplay. "Beef up" is an idiomatic expression that means to improve or increase something, often
# ...
